# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="25MJRm1ewmhKVupUpjz6")
project = rf.workspace("sree-69ula").project("cats-and-dogs-hapzd")
version = project.version(1)
dataset = version.download("yolov8")

# %%
# !pip install ultralytics
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display

# %%
from ultralytics import YOLO
model = YOLO('yolov8s.pt')

results = model.train(data='/content/cats-and-dogs-1/data.yaml', epochs=50)
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model= YOLO('/content/drive/MyDrive/IAs Treinadas/Cats and Dogs/runs/detect/train2/weights/best.pt')
model.export(format='ONNX')
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/IAs Treinadas/Cats and Dogs/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (21.5 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 71.8 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 9.1s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 10.7s, saved as '/content/drive/MyDrive/IAs Treinadas/Cats and Dogs/runs/detect/train2/weights/best.onnx' (42.6 MB)
#
# Export complete (14.3s)
# ...

# %%
from IPython.display import Image

Image(filename=f'/content/drive/MyDrive/IAs Treinadas/Cats and Dogs/runs/detect/train2/train_batch2.jpg', width=900)
